# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# Veri Yükleme
train_data_dir = "./tumor/training"
test_data_dir = "./tumor/testing"
img_width, img_height = 224, 224

# Veri Artırma (Data Augmentation)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='categorical'
)

# ResNet50 modelini kullanarak yeni modeli oluşturun
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))

# Mevcut modeli (Sequential) oluşturun
model = Sequential()
model.add(resnet_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))  # Dropout ekleyerek aşırı öğrenmeyi azaltın
model.add(Dense(4, activation='softmax'))

# Modeli derleyin
model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Model Eğitimi
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // 32,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // 32
)

# Eğitim süreci sırasında kayıp ve doğruluk değerlerini alın
loss = history.history['loss']
accuracy = history.history['accuracy']

# Doğrulama (validation) seti üzerindeki kayıp ve doğruluk değerlerini alın (varsa)
val_loss = history.history.get('val_loss')
val_accuracy = history.history.get('val_accuracy')

# Eğitim kaybını (loss) grafiğe çizin
plt.plot(loss, label='Training Loss')
# Doğrulama kaybını (loss) grafiğe çizin (varsa)
if val_loss:
    plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Doğruluk (accuracy) grafiğini çizin
plt.plot(accuracy, label='Training Accuracy')
# Doğrulama doğruluğunu (accuracy) grafiğe çizin (varsa)
if val_accuracy:
    plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Eğitilen modeli kaydetmek istiyorsanız:
model.save("tumor_resnet_model.h5")
# Out:
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.
# /Users/kubra/anaconda3/envs/myenv/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 2024-02-01 13:36:26.648885: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2024-02-01 13:36:26.649531: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/50
# 178/178 [==============================] - 1829s 10s/step - loss: 0.5712 - accuracy: 0.8505 - val_loss: 5.9307 - val_accuracy: 0.3094
# Epoch 2/50
# 178/178 [==============================] - 1918s 11s/step - loss: 0.1669 - accuracy: 0.9461 - val_loss: 4.5775 - val_accuracy: 0.2961
# Epoch 3/50
# 178/178 [==============================] - 1905s 11s/step - loss: 0.1083 - accuracy: 0.9671 - val_loss: 3.7823 - val_accuracy: 0.4250
# Epoch 4/50
# 178/178 [==============================] - 1916s 11s/step - loss: 0.0800 - accuracy: 0.9732 - val_loss: 1.7423 - val_accuracy: 0.5820
# Epoch 5/50
# 178/178 [==============================] - 1907s 11s/step - loss: 0.0634 - accuracy: 0.9783 - val_loss: 0.7215 - val_accuracy: 0.7828
# Epoch 6/50
# 178/178 [==============================] - 68257s 386s/step - loss: 0.0958 - accuracy: 0.9780 - val_loss: 1.3921 - val_accuracy: 0.7094
# Epoch 7/50
# 178/178 [==============================] - 2662s 14s/step - loss: 0.0727 - accuracy: 0.9792 - val_loss: 0.0692 - val_accuracy: 0.9812
# Epoch 8/50
# 178/178 [==============================] - 5382s 30s/step - loss: 0.0482 - accuracy: 0.9884 - val_loss: 0.0372 - val_accuracy: 0.9891
# Epoch 9/50
# 178/178 [==============================] - 1820s 10s/step - loss: 0.0481 - accuracy: 0.9870 - val_loss: 0.6086 - val_accuracy: 0.9625
# Epoch 10/50
# 178/178 [==============================] - 1896s 11s/step - loss: 0.0205 - accuracy: 0.9926 - val_loss: 0.0329 - val_accuracy: 0.9914
# Epoch 11/50
# 178/178 [==============================] - 1913s 11s/step - loss: 0.2579 - accuracy: 0.9750 - val_loss: 39.4554 - val_accuracy: 0.3703
# Epoch 12/50
# 178/178 [==============================] - 1962s 11s/step - loss: 0.1184 - accuracy: 0.9759 - val_loss: 1.2316 - val_accuracy: 0.8273
# Epoch 13/50
# 178/178 [==============================] - 1911s 11s/step - loss: 0.1151 - accuracy: 0.9798 - val_loss: 0.2760 - val_accuracy: 0.9711
# Epoch 14/50
# 178/178 [==============================] - 1857s 10s/step - loss: 0.0560 - accuracy: 0.9877 - val_loss: 0.0358 - val_accuracy: 0.9883
# Epoch 15/50
# 178/178 [==============================] - 1823s 10s/step - loss: 0.0291 - accuracy: 0.9903 - val_loss: 0.0246 - val_accuracy: 0.9930
# Epoch 16/50
# 178/178 [==============================] - 28247s 160s/step - loss: 0.0391 - accuracy: 0.9908 - val_loss: 0.0689 - val_accuracy: 0.9773
# Epoch 17/50
# 178/178 [==============================] - 1830s 10s/step - loss: 0.0360 - accuracy: 0.9907 - val_loss: 0.0676 - val_accuracy: 0.9844
# Epoch 18/50
# 178/178 [==============================] - 1926s 11s/step - loss: 0.0807 - accuracy: 0.9868 - val_loss: 0.3573 - val_accuracy: 0.9367
# Epoch 19/50
# 178/178 [==============================] - 1979s 11s/step - loss: 0.0470 - accuracy: 0.9871 - val_loss: 0.0480 - val_accuracy: 0.9883
# Epoch 20/50
# 178/178 [==============================] - 1900s 11s/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 0.0506 - val_accuracy: 0.9875
# Epoch 21/50
# 178/178 [==============================] - 1906s 11s/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.0219 - val_accuracy: 0.9969
# Epoch 22/50
# 178/178 [==============================] - 1892s 11s/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0352 - val_accuracy: 0.9953
# Epoch 23/50
# 178/178 [==============================] - 1924s 11s/step - loss: 0.0201 - accuracy: 0.9952 - val_loss: 0.0770 - val_accuracy: 0.9805
# Epoch 24/50
# 178/178 [==============================] - 1910s 11s/step - loss: 0.0411 - accuracy: 0.9875 - val_loss: 0.0611 - val_accuracy: 0.9891
# Epoch 25/50
# 178/178 [==============================] - 1895s 11s/step - loss: 0.0306 - accuracy: 0.9919 - val_loss: 0.1030 - val_accuracy: 0.9789
# Epoch 26/50
# 178/178 [==============================] - 1892s 11s/step - loss: 0.0279 - accuracy: 0.9931 - val_loss: 0.0816 - val_accuracy: 0.9766
# Epoch 27/50
# 178/178 [==============================] - 1897s 11s/step - loss: 0.0615 - accuracy: 0.9879 - val_loss: 0.1804 - val_accuracy: 0.9594
# Epoch 28/50
# 178/178 [==============================] - 1863s 10s/step - loss: 0.0518 - accuracy: 0.9868 - val_loss: 0.1283 - val_accuracy: 0.9750
# Epoch 29/50
# 178/178 [==============================] - 1870s 11s/step - loss: 0.0278 - accuracy: 0.9928 - val_loss: 0.0617 - val_accuracy: 0.9852
# Epoch 30/50
# 178/178 [==============================] - 1891s 11s/step - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.0181 - val_accuracy: 0.9969
# Epoch 31/50
# 178/178 [==============================] - 1901s 11s/step - loss: 0.0158 - accuracy: 0.9963 - val_loss: 0.0268 - val_accuracy: 0.9945
# Epoch 32/50
# 178/178 [==============================] - 1900s 11s/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.0287 - val_accuracy: 0.9961
# Epoch 33/50
# 178/178 [==============================] - 1934s 11s/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.0267 - val_accuracy: 0.9930
# Epoch 34/50
# 178/178 [==============================] - 1899s 11s/step - loss: 0.0102 - accuracy: 0.9977 - val_loss: 0.0298 - val_accuracy: 0.9961
# Epoch 35/50
# 178/178 [==============================] - 1936s 11s/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0251 - val_accuracy: 0.9930
# Epoch 36/50
# 178/178 [==============================] - 1906s 11s/step - loss: 0.0236 - accuracy: 0.9952 - val_loss: 0.1327 - val_accuracy: 0.9656
# Epoch 37/50
# 178/178 [==============================] - 1978s 11s/step - loss: 0.0328 - accuracy: 0.9900 - val_loss: 0.2325 - val_accuracy: 0.9594
# Epoch 38/50
# 178/178 [==============================] - 1999s 11s/step - loss: 0.0157 - accuracy: 0.9940 - val_loss: 0.0592 - val_accuracy: 0.9875
# Epoch 39/50
# 178/178 [==============================] - 2016s 11s/step - loss: 0.0551 - accuracy: 0.9894 - val_loss: 0.0215 - val_accuracy: 0.9945
# Epoch 40/50
# 178/178 [==============================] - 2089s 12s/step - loss: 0.0310 - accuracy: 0.9938 - val_loss: 0.2675 - val_accuracy: 0.9812
# Epoch 41/50
# 178/178 [==============================] - 2073s 12s/step - loss: 0.0254 - accuracy: 0.9931 - val_loss: 0.0550 - val_accuracy: 0.9867
# Epoch 42/50
# 178/178 [==============================] - 2003s 11s/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0239 - val_accuracy: 0.9969
# Epoch 43/50
# 178/178 [==============================] - 2002s 11s/step - loss: 0.0104 - accuracy: 0.9970 - val_loss: 0.0124 - val_accuracy: 0.9969
# Epoch 44/50
# 178/178 [==============================] - 2150s 12s/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.0879 - val_accuracy: 0.9766
# Epoch 45/50
# 178/178 [==============================] - 2104s 12s/step - loss: 0.0271 - accuracy: 0.9933 - val_loss: 0.0288 - val_accuracy: 0.9937
# Epoch 46/50
# 178/178 [==============================] - 2234s 13s/step - loss: 0.0361 - accuracy: 0.9935 - val_loss: 0.0241 - val_accuracy: 0.9945
# Epoch 47/50
# 131/178 [=====================>........] - ETA: 9:18 - loss: 0.0217 - accuracy: 0.9948
